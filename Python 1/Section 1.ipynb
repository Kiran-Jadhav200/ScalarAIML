# %% [markdown]
# ## Introduction to Python

# %%
# lets start with Hello
#print - inbuilt function 
#python is case sensitive
print("hello world");
# Out:
# hello world

# %%
print(123)
# Out:
# 123

# %%
print(123 + 123)
# Out:
# 246

# %%
print("123")
# Out:
# 123

# %%
print("123"+"123")
# Out:
# 123123

# %%
a = "13.56"
print(float(a))
# Out:
# 13.56
